# %% [markdown]
# <a href="https://colab.research.google.com/github/Krutika12345/assignment-3/blob/main/assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
z=sns.load_dataset('fmri')
z.head(7)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
# 5      s9         18  stim  parietal -0.103513
# 6      s8         18  stim  parietal -0.064408

# %%
sns.relplot(x='timepoint',y='signal',hue='event',data=z)

# %%
sns.relplot(x='timepoint',y='signal',hue='event',data=z,kind='line')

# %%
sns.catplot(x="timepoint",y='signal',hue='event',kind='box',data=z)
